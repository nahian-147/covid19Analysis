# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import ipywidgets as widgets

# %%
data = pd.read_csv('covid-data.csv')

# %%
data
# Out:
#            date     location  total_cases  new_cases  total_deaths  new_deaths
# 0      31-12-19  Afghanistan          0.0        0.0           0.0         0.0
# 1      01-01-20  Afghanistan          0.0        0.0           0.0         0.0
# 2      02-01-20  Afghanistan          0.0        0.0           0.0         0.0
# 3      03-01-20  Afghanistan          0.0        0.0           0.0         0.0
# 4      04-01-20  Afghanistan          0.0        0.0           0.0         0.0
# ...         ...          ...          ...        ...           ...         ...
# 26350  23-06-20     Zimbabwe        512.0       23.0           6.0         0.0
# 26351  24-06-20     Zimbabwe        525.0       13.0           6.0         0.0
# 26352  25-06-20     Zimbabwe        530.0        5.0           6.0         0.0
# 26353  26-06-20     Zimbabwe        551.0       21.0           6.0         0.0
# 26354  27-06-20     Zimbabwe        561.0       10.0           6.0         0.0
#
# ...

# %%
countries = data['location'].unique()

# %%
def DeathByCountries(country):
    # %matplotlib inline
    
    cntryData = data[data['location']==country]
    cntryData = cntryData.dropna()
    ttlCase = cntryData['total_cases']
    nwCase = cntryData['new_cases']
    ttlDeath = cntryData[cntryData['total_deaths']>0].total_deaths
    nwDeath = cntryData['new_deaths']
    dateDth = cntryData[cntryData['total_deaths']>0].date
    date = cntryData['date']
    
    plt.figure(figsize=(55,20))
    
    plt.suptitle('Date vs Total Death and Daily New Death of '+str(country),fontsize = 55)
    
    plt.subplot(2, 1, 1)
    plt.bar(dateDth,ttlDeath,color=sns.color_palette('Greys',len(dateDth)),width=0.3)
    plt.yticks(fontsize=25)
    plt.xticks(rotation=90)
    plt.xlabel('Date',fontsize=40)
    plt.ylabel('Total Death',fontsize=40)
    
    plt.subplot(2, 1, 2)
    plt.bar(date, nwDeath,color='Grey',width=0.27)
    plt.xlabel('Date',fontsize=40)
    plt.ylabel('New Death',fontsize=40)
    plt.yticks(fontsize=25)
    plt.xticks(rotation=90)

# %%
DeathByCountries('United States')

# %%
Countries = widgets.Dropdown(
            options=countries,
            disabled=False,
            )

# %%
widgets.interact(DeathByCountries,country=countries);
# Out:
# interactive(children=(Dropdown(description='country', options=('Afghanistan', 'Albania', 'Algeria', 'Andorra',…

# %%
def CaseByCountries(country):
    # %matplotlib inline
    
    cntryData = data[data['location']==country]
    cntryData = cntryData.dropna()
    ttlCase = cntryData['total_cases']
    nwCase = cntryData['new_cases']
    date = cntryData['date']
    
    plt.figure(figsize=(55,20))
    
    plt.suptitle('Date vs Total Case and Daily New Case of '+str(country),fontsize = 55)
    
    plt.subplot(2, 1, 1)
    plt.bar(date,ttlCase,color=sns.color_palette('Greys',len(date)),width=0.3)
    plt.yticks(fontsize=25)
    plt.xticks(rotation=90)
    plt.xlabel('Date',fontsize=40)
    plt.ylabel('Total Case',fontsize=40)
    
    plt.subplot(2, 1, 2)
    plt.bar(date, nwCase,color='Grey',width=0.3)
    plt.xlabel('Date',fontsize=40)
    plt.ylabel('New Case',fontsize=40)
    plt.yticks(fontsize=25)
    plt.xticks(rotation=90)

# %%
CaseByCountries('Bangladesh')

# %%
def PlotCase_vs_Death(country):
    # %matplotlib inline
    
    
    cntryData = data[data['location']==country]
    cntryData = cntryData.dropna()
    ttlCase = cntryData['total_cases']
    ttlDeath = cntryData['total_deaths']
    
    plt.figure(figsize=(30,10))
    plt.plot(ttlCase,ttlDeath,color='Grey')
    plt.plot(ttlCase,ttlDeath,'ko')
    plt.xlabel('Total Cases',fontsize = 35)
    plt.ylabel('Total Deaths',fontsize = 35)
    plt.xticks(fontsize = 25)
    plt.yticks(fontsize = 25)
    plt.title('Total Case vs Total Deaths of '+str(country),fontsize = 40)

# %%
PlotCase_vs_Death('Bangladesh')

# %%
def PlotDteTtlCsDth(country):
    # %matplotlib inline
    
    cntryData = data[data['location']==country]
    cntryData = cntryData.dropna()
    ttlCase = cntryData['total_cases']
    ttlDeath = cntryData['total_deaths']
    date = cntryData['date']
    
    plt.figure(figsize=(30,10))
    plt.suptitle('Date vs Total Case and Total Death of '+str(country),fontsize = 57)
    
    plt.subplot(2, 1, 1)
    plt.plot(date,ttlCase,color='Grey')
    plt.plot(date,ttlCase,'ko')
    plt.xlabel('Date',fontsize = 40)
    plt.ylabel('Total Case',fontsize = 40)
    plt.xticks(fontsize =10,rotation=90)
    plt.yticks(fontsize = 25)
    
    plt.subplot(2, 1, 2)
    plt.plot(date,ttlDeath,'grey')
    plt.plot(date,ttlDeath,'ko')
    plt.xlabel('Date',fontsize = 40)
    plt.ylabel('Total Death',fontsize = 40)
    plt.xticks(fontsize =10,rotation=90)
    plt.yticks(fontsize = 25)

# %%
def PlotTtlCase_vs_NwCase(country):
    # %matplotlib inline
    
    cntryData = data[data['location']==country]
    cntryData = cntryData.dropna()
    ttlCase = cntryData['total_cases']
    nwCase = cntryData['new_cases']
    
    plt.figure(figsize=(30,10))
    plt.plot(ttlCase,nwCase,color='Grey')
    plt.plot(ttlCase,nwCase,'ko')
    plt.xlabel('Total Cases',fontsize = 35)
    plt.ylabel('New Cases',fontsize = 35)
    plt.xticks(fontsize = 25)
    plt.yticks(fontsize = 25)
    plt.title('Total Case vs New Case of '+str(country),fontsize = 45)

# %%
Functions = widgets.Dropdown(
            options=[('Total Case vs New Case',PlotTtlCase_vs_NwCase),
                     ('Total Case vs Total Death',PlotCase_vs_Death),
                     ('Total Case and Daily New Case',CaseByCountries),
                     ('Total Death and Daily New Death',DeathByCountries),
                     ('Date vs Total Case and Total Death',PlotDteTtlCsDth)],
            disabled=False,
            )

# %%
def myPlot(country,PlotFun):
    PlotFun(country)

# %%
widgets.interact(myPlot,country=countries,PlotFun=Functions);
# Out:
# interactive(children=(Dropdown(description='country', options=('Afghanistan', 'Albania', 'Algeria', 'Andorra',…

# %%
def DeathByCountriesCmp(country1,country2,country3):
    # %matplotlib inline
    
    c1 = data[data['location']==country1]
    c1 = c1.dropna()
    ttlCase1 = c1['total_cases']
    nwCase1 = c1['new_cases']
    ttlDeath1 = c1[c1['total_deaths']>0].total_deaths
    nwDeath1 = c1['new_deaths']
    dateDth1 = c1[c1['total_deaths']>0].date
    date1 = c1['date']

    c2 = data[data['location']==country2]
    c2 = c2.dropna()
    ttlCase2 = c2['total_cases']
    nwCase2 = c2['new_cases']
    ttlDeath2 = c2[c2['total_deaths']>0].total_deaths
    nwDeath2 = c2['new_deaths']
    dateDth2 = c2[c2['total_deaths']>0].date
    date2 = c2['date']

    c3 = data[data['location']==country3]
    c3 = c3.dropna()
    ttlCase3 = c3['total_cases']
    nwCase3 = c3['new_cases']
    ttlDeath3 = c3[c3['total_deaths']>0].total_deaths
    nwDeath3 = c3['new_deaths']
    dateDth3 = c3[c3['total_deaths']>0].date
    date3 = c3['date']

    
    plt.figure(figsize=(55,20))
    
    plt.suptitle('Date vs Total Death and Daily New Death of %s, %s and %s'%(country1,country2,country3),fontsize = 55)
    
    plt.subplot(2, 3, 1)
    plt.bar(dateDth1,ttlDeath1,color=sns.color_palette('Greys',len(dateDth1)),width=0.3)
    plt.yticks(fontsize=25)
    plt.xticks(rotation=90)
    plt.ylabel('Total Death',fontsize=40)

    plt.subplot(2, 3, 2)
    plt.bar(dateDth2,ttlDeath2,color=sns.color_palette('Greys',len(dateDth2)),width=0.3)
    plt.yticks(fontsize=25)
    plt.xticks(rotation=90)
    
    plt.subplot(2, 3, 3)
    plt.bar(dateDth3,ttlDeath3,color=sns.color_palette('Greys',len(dateDth3)),width=0.3)
    plt.yticks(fontsize=25)
    plt.xticks(rotation=90)
    
    plt.subplot(2, 3, 4)
    plt.plot(date1, nwDeath1,'grey')
    plt.plot(date1, nwDeath1,'ko')
    plt.xlabel('Date',fontsize=40)
    plt.ylabel('New Death',fontsize=40)
    plt.yticks(fontsize=25)
    plt.xticks(rotation=90)
    
    plt.subplot(2, 3, 5)
    plt.plot(date2, nwDeath2,'grey')
    plt.plot(date2, nwDeath2,'ko')
    plt.xlabel('Date',fontsize=40)
    plt.yticks(fontsize=25)
    plt.xticks(rotation=90)
    
    plt.subplot(2, 3, 6)
    plt.plot(date3, nwDeath3,'grey')
    plt.plot(date3, nwDeath3,'ko')
    plt.xlabel('Date',fontsize=40)
    plt.yticks(fontsize=25)
    plt.xticks(rotation=90)

# %%
DeathByCountriesCmp('Bangladesh','India','Pakistan')

# %%
def CaseByCountriesCmp(country1,country2,country3):
    # %matplotlib inline
    
    c1 = data[data['location']==country1]
    c1 = c1.dropna()
    ttlCase1 = c1['total_cases']
    nwCase1 = c1['new_cases']
    ttlDeath1 = c1[c1['total_deaths']>0].total_deaths
    nwDeath1 = c1['new_deaths']
    dateDth1 = c1[c1['total_deaths']>0].date
    date1 = c1['date']

    c2 = data[data['location']==country2]
    c2 = c2.dropna()
    ttlCase2 = c2['total_cases']
    nwCase2 = c2['new_cases']
    ttlDeath2 = c2[c2['total_deaths']>0].total_deaths
    nwDeath2 = c2['new_deaths']
    dateDth2 = c2[c2['total_deaths']>0].date
    date2 = c2['date']

    c3 = data[data['location']==country3]
    c3 = c3.dropna()
    ttlCase3 = c3['total_cases']
    nwCase3 = c3['new_cases']
    ttlDeath3 = c3[c3['total_deaths']>0].total_deaths
    nwDeath3 = c3['new_deaths']
    dateDth3 = c3[c3['total_deaths']>0].date
    date3 = c3['date']

    
    plt.figure(figsize=(55,20))
    
    plt.suptitle('Date vs Total Cases and Daily New Cases of %s, %s and %s'%(country1,country2,country3),fontsize = 55)
    
    plt.subplot(2, 3, 1)
    plt.bar(date1,ttlCase1,color=sns.color_palette('Greys',len(date1)),width=0.3)
    plt.yticks(fontsize=25)
    plt.xticks(rotation=90)
    plt.ylabel('Total Case',fontsize=40)

    plt.subplot(2, 3, 2)
    plt.bar(date2,ttlCase2,color=sns.color_palette('Greys',len(date2)),width=0.3)
    plt.yticks(fontsize=25)
    plt.xticks(rotation=90)
    
    plt.subplot(2, 3, 3)
    plt.bar(date3,ttlCase3,color=sns.color_palette('Greys',len(date3)),width=0.3)
    plt.yticks(fontsize=25)
    plt.xticks(rotation=90)
    
    plt.subplot(2, 3, 4)
    plt.plot(date1, nwCase1,'grey')
    plt.plot(date1, nwCase1,'ko')
    plt.xlabel('Date',fontsize=40)
    plt.ylabel('New Case',fontsize=40)
    plt.yticks(fontsize=25)
    plt.xticks(rotation=90)
    
    plt.subplot(2, 3, 5)
    plt.plot(date2, nwCase2,'grey')
    plt.plot(date2, nwCase2,'ko')
    plt.xlabel('Date',fontsize=40)
    plt.yticks(fontsize=25)
    plt.xticks(rotation=90)
    
    plt.subplot(2, 3, 6)
    plt.plot(date3, nwCase3,'grey')
    plt.plot(date3, nwCase3,'ko')
    plt.xlabel('Date',fontsize=40)
    plt.yticks(fontsize=25)
    plt.xticks(rotation=90)

# %%
CaseByCountriesCmp('Bangladesh','India','Pakistan')

# %%
CmpFunctions = widgets.Dropdown(
            options=[('Total Case and Daily New Case',CaseByCountriesCmp),
                     ('Total Death and Daily New Death',DeathByCountriesCmp)],
            disabled=False,
            )

# %%
def myPlot(country1,country2,country3,PlotFun):
    PlotFun(country1,country2,country3)

# %%
widgets.interact(myPlot,country1=countries,country2=countries,country3=countries,PlotFun=CmpFunctions);
# Out:
# interactive(children=(Dropdown(description='country1', options=('Afghanistan', 'Albania', 'Algeria', 'Andorra'…
